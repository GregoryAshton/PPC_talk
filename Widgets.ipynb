# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# %% [markdown]
# # Using widgets in the ipython notebook
#
# - Here is a fairly over the top use of some of the most recent features to the ipython notebook.
#
# You will neeed at least `ipython v2` to use these features. You can check this by
# running `$ipython --version` from the command line
#
# ## Lorenz attractor

# %%
def lorenz(ys, t, s, r, b) :
    " Defined the ODEs for the Lorenz attractor "
    [x, y, z] = ys
    x_dot = s*(y - x)
    y_dot = r*x - y - x*z
    z_dot = x*y - b*z
    return x_dot, y_dot, z_dot

time = np.linspace(0, 100, 10000)
results = odeint(lorenz, y0=[0.0, 1.0, 1.05], t=time, args=(10, 28, 2.667))

plt.plot(results[:, 0], results[:, 2])
plt.show()

# %% [markdown]
# ## Interactive Lorenz attractor
#
# Now we will make it 3D and interative

# %%
from mpl_toolkits.mplot3d import Axes3D

def solve_lorenz(s, r, b):
    def lorenz(ys, t, s, r, b) :
        [x, y, z] = ys
        x_dot = s*(y - x)
        y_dot = r*x - y - x*z
        z_dot = x*y - b*z
        return x_dot, y_dot, z_dot

    time = np.linspace(0, 100, 10000)
    results = odeint(lorenz, y0=[0.0, 1.0, 1.05], t=time, args=(s, r, b))

    fig = plt.figure()
    ax = fig.gca(projection='3d')
    ax.plot(results[:, 0], results[:, 1], results[:, 2])
    plt.show()

# %%
from IPython.html.widgets import interact, interactive, fixed

interactive(solve_lorenz, s=10, r=28, b=fixed(2.667))
